# %%
#from cassandra.cluster import Cluster
import pandas as pd 
import collections
import numpy as np

# %%
import csv

col_list = ["movieId", "title","genres"]

df = pd.read_csv("/home/spetz/Downloads/archive/movie.csv", usecols=col_list)
#file.readlines()

# %%
df=df.drop(columns=["genres","movieId"])

# %%
columns_list = ["userId", "movieId","rating","timestamp"]
dx=pd.read_csv("/home/spetz/Downloads/archive/rating.csv", usecols=columns_list)
dx
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
dx=dx.drop(columns=["userId"])
dx
# Out:
#           movieId  rating            timestamp
# 0               2     3.5  2005-04-02 23:53:47
# 1              29     3.5  2005-04-02 23:31:16
# 2              32     3.5  2005-04-02 23:33:39
# 3              47     3.5  2005-04-02 23:32:07
# 4              50     3.5  2005-04-02 23:29:40
# ...           ...     ...                  ...
# 20000258    68954     4.5  2009-11-13 15:42:00
# 20000259    69526     4.5  2009-12-03 18:31:48
# 20000260    69644     3.0  2009-12-07 18:10:57
# 20000261    70286     5.0  2009-11-13 15:42:24
# 20000262    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 3 columns]

# %%
from nltk import word_tokenize
a_list=list()
dxx = dx[(dx['timestamp'] > '2015-01-01') & (dx['timestamp'] <= '2015-01-15')]
for i in range(len(dxx)):
    ar = dx.loc[(dx['movieId'] == i ) & (dx['rating'] <= 10)] 
    a_list.append(ar['movieId'].values)
new_movies=' '.join(map(str,a_list))
    

tokenized_movies = word_tokenize(new_movies)

dict_freq={}
for word in tokenized_movies:
    if word not in dict_freq:
        dict_freq[word] =1
    else:
        dict_freq[word] +=1
dict_freq
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/spetz/Desktop/big_data.ipynb Cell 6' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/spetz/Desktop/big_data.ipynb#ch0000005?line=1'>2</a> a_list=list()
#       <a href='vscode-notebook-cell:/home/spetz/Desktop/big_data.ipynb#ch0000005?line=2'>3</a> for i in range(len(dx['timestamp'] > '2015-01-01 14:29:36')):
# ----> <a href='vscode-notebook-cell:/home/spetz/Desktop/big_data.ipynb#ch0000005?line=3'>4</a>     ar = dx.loc[(dx['movieId'] == i ) & (dx['rating'] <= 10) & (dx['timestamp'] > '2015-01-01 14:29:36')]
#       <a href='vscode-notebook-cell:/home/spetz/Desktop/big_data.ipynb#ch0000005?line=4'>5</a>     a_list.append(ar['movieId'].values)
#       <a href='vscode-notebook-cell:/home/spetz/Desktop/big_data.ipynb#ch0000005?line=5'>6</a> new_movies=' '.join(map(str,a_list))
#
# ...

# %%
new_list = list()
dxx = dx[(dx['timestamp'] > '2015-01-10') & (dx['timestamp'] <= '2015-01-11')]
for i in range(len(dxx)):
    ar = dx.loc[(dx['movieId'] == i ) & (dx['rating'] <= 10)]
    rating=ar.apply("rating").sum()
    movies_num=ar['movieId'].value_counts()
    x=sum(rating/movies_num)
    new_list.append(x)
    print("To rating tis taineias me movie id: %d einai :%s" %((i),(x)))
# Out:
# To rating tis taineias me movie id: 0 einai :0
# To rating tis taineias me movie id: 1 einai :3.921239561324077
# To rating tis taineias me movie id: 2 einai :3.2119768016904193
# To rating tis taineias me movie id: 3 einai :3.1510404397330194
# To rating tis taineias me movie id: 4 einai :2.8613933236574747
# To rating tis taineias me movie id: 5 einai :3.064591727653976
# To rating tis taineias me movie id: 6 einai :3.8349303318130468
# To rating tis taineias me movie id: 7 einai :3.3664840675873777
# To rating tis taineias me movie id: 8 einai :3.142049469964664
# To rating tis taineias me movie id: 9 einai :3.0049242424242424
# To rating tis taineias me movie id: 10 einai :3.430029305292191
# To rating tis taineias me movie id: 11 einai :3.667712806959586
# To rating tis taineias me movie id: 12 einai :2.6197659297789335
# To rating tis taineias me movie id: 13 einai :3.272416153319644
# To rating tis taineias me movie id: 14 einai :3.432082364662903
# ...

# %%
df = pd.DataFrame (new_list, columns = ['rating'])
x= df['rating'] 
list_n=list()
for i in x:
    if i>4.185:
        list_n.append(i)

list_n
# Out:
# [4.334372207803259,
#  4.190671901948552,
#  4.446990499637029,
#  4.310175010988133,
#  4.247286821705426,
#  4.364732196832306,
#  4.271333600779414,
#  4.233538107122288,
#  4.258326830670664,
#  4.187211791831357,
#  4.256934865900383,
#  4.2041027766266055,
#  4.1977899432279,
#  4.2326233183856505,
#  4.24807897901911,
#  4.188202061218635,
#  4.219009123455364,
#  4.224137931034483,
#  4.188943056401923,
#  4.246001523229246,
#  4.275640557704942,
#  4.199673416067929,
#  4.193171077504726,
#  4.207361186471333,
#  4.2741796572216,
#  4.187185880702848,
#  4.227123123722136,
#  4.211716774374825,
#  4.666666666666667,
#  4.224281931146873]

# %%
from nltk import word_tokenize
a_list=list()
dxx = dx[(dx['timestamp'] > '2015-01-01') & (dx['timestamp'] <= '2015-01-02')]
for i in range(len(dxx)):
    ar = dx.loc[(dx['movieId'] == i ) & (dx['rating'] <= 10)] 
    a_list.append(ar['movieId'].values)
new_movies=' '.join(map(str,a_list))
    

tokenized_movies = word_tokenize(new_movies)

dict_freq={}
for word in tokenized_movies:
    if word not in dict_freq:
        dict_freq[word] =1
    else:
        dict_freq[word] +=1
dict_freq
# Out:
# {'[': 4916,
#  ']': 4916,
#  '1': 6,
#  '...': 2201,
#  '2': 6,
#  '3': 6,
#  '4': 6,
#  '5': 6,
#  '6': 6,
#  '7': 6,
#  '8': 6,
#  '9': 6,
#  '10': 6,
#  '11': 6,
#  '12': 6,
#  '13': 6,
#  '14': 6,
#  '15': 6,
#  '16': 6,
#  '17': 6,
#  '18': 6,
#  '19': 6,
#  '20': 6,
#  '21': 6,
#  '22': 6,
#  '23': 6,
#  '24': 6,
#  '25': 6,
#  '26': 6,
#  '27': 6,
#  '28': 6,
#  '29': 6,
#  '30': 6,
#  '31': 6,
#  '32': 6,
#  '33': 65,
#  '34': 6,
#  '35': 6,
#  '36': 6,
#  '37': 85,
#  '38': 552,
#  '39': 6,
#  '40': 886,
#  '41': 6,
#  '42': 6,
#  '43': 6,
#  '44': 6,
#  '45': 6,
#  '46': 6,
#  '47': 6,
#  '48': 6,
#  '49': 236,
#  '50': 6,
#  '51': 27,
#  '52': 6,
#  '53': 150,
#  '54': 956,
#  '55': 939,
#  '56': 70,
#  '57': 6,
#  '58': 6,
#  '59': 191,
#  '60': 6,
#  '61': 6,
#  '62': 6,
#  '63': 6,
#  '64': 6,
#  '65': 6,
#  '66': 6,
#  '67': 170,
#  '68': 6,
#  '69': 6,
#  '70': 6,
#  '71': 6,
#  '72': 6,
#  '73': 6,
#  '74': 6,
#  '75': 558,
#  '76': 6,
#  '77': 221,
#  '78': 6,
# ...

# %%
#query1=pd.concat([df, dx], axis=1, ignore_index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///home/spetz/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///home/spetz/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///home/spetz/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
# Out:
# Counter({3.5: 2200156,
#          4.0: 5561926,
#          3.0: 4291193,
#          4.5: 1534824,
#          5.0: 2898660,
#          2.0: 1430997,
#          1.0: 680732,
#          2.5: 883398,
#          0.5: 239125,
#          1.5: 279252})
